# %%
import os

# %%
from os import makedirs

# %%
from os import listdir

# %%
from shutil import copyfile

# %%
from random import seed

# %%
from random import random

# %%
import numpy as np

# %%
import pandas as pd

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib.image import imread

# %%
from PIL import Image

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay

# %%
import tensorflow as tf

# %%
pip uninstall keras tensorflow -y
# Out:
# Found existing installation: keras 3.2.1
# Uninstalling keras-3.2.1:
#   Successfully uninstalled keras-3.2.1
# Found existing installation: tensorflow 2.16.1
# Uninstalling tensorflow-2.16.1:
#   Successfully uninstalled tensorflow-2.16.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras tensorflow
# Out:
# ...
#   Using cached tensorflow-2.17.0-cp39-cp39-win_amd64.whl (2.0 kB)
# Note: you may need to restart the kernel to use updated packages.
# ...
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gnapikasaiede\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gnapikasaiede\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gnapikasaiede\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gnapikasaiede\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gnapikasaiede\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gnapikasaiede\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow-intel (c:\users\gnapikasaiede\anaconda3\lib\site-packages)
# ...

# %%
from tensorflow.keras.models import Sequential

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
from tensorflow.keras.layers import Dense,MaxPooling2D,Dropout,Flatten,BatchNormalization,Conv2D

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau,EarlyStopping

# %%
train_path = "C:\\Users\\gnapikasaiede\\Downloads\\archive\\train"
test_path = "C:\\Users\\gnapikasaiede\\Downloads\\archive\\test"

files = "/kaggle/working/"

# %%
import os
image_dir = "C:\\Users\\gnapikasaiede\\Downloads\\archive\\train"

# %%
import os
filenames = os.listdir(image_dir)
labels = [x.split(".")[0] for x in filenames]

# %%
data = pd.DataFrame({"filename": filenames, "label": labels})

data.head()
# Out:
#   filename label
# 0     cats  cats
# 1     dogs  dogs

# %%
plt.figure(figsize=(20,20)) # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)

# %%
filename = "C:\\Users\\gnapikasaiede\\Downloads\\archive\\train\\dogs\\dog.9968.jpg"
image = imread(filename)
plt.imshow(image)
plt.title('Dog',fontsize=12)
plt.axis('off')

plt.show()

# %%
filename = "C:\\Users\\gnapikasaiede\\Downloads\\archive\\train\\cats\\cat.9963.jpg"
image = imread(filename)
plt.imshow(image)
plt.title('Cat',fontsize=12)
plt.axis('off')
plt.show()

# %%
image_dir = "C:\\Users\\gnapikasaiede\\Downloads\\archive\\image dataset"

filenames = os.listdir(image_dir)
labels = [x.split(".")[0] for x in filenames]

data = pd.DataFrame({"filename": filenames, "label": labels})

data.head()
# Out:
#        filename label
# 0  cat.9957.jpg   cat
# 1  cat.9959.jpg   cat
# 2  cat.9960.jpg   cat
# 3  cat.9961.jpg   cat
# 4  cat.9962.jpg   cat

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Set the path to your image directory
image_dir = r"C:\Users\gnapikasaiede\Downloads\archive\image dataset"

plt.figure(figsize=(20, 20))  # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)

for i in range(10):
    plt.subplot(1, 10, i + 1)  # 1 row and 10 columns
    filename = f'{image_dir}\\dog.{9907 + i}.jpg'  # Adjusted filename pattern
    try:
        image = imread(filename)
        plt.imshow(image)
        plt.title('Dog', fontsize=12)
        plt.axis('off')
    except FileNotFoundError:
        print(f"File not found: {filename}")

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

# Set the path to your image directory
image_dir = r"C:/Users/gnapikasaiede/Downloads/archive/train/cats"

plt.figure(figsize=(20, 20))  # specifying the overall grid size
plt.subplots_adjust(hspace=0.4)

for i in range(10):
    plt.subplot(1, 10, i + 1)  # 1 row and 10 columns
    filename = f'{image_dir}\\cat.{9970 + i}.jpg'  # Adjusted filename pattern
    try:
        image = imread(filename)
        plt.imshow(image)
        plt.title('cat', fontsize=12)
        plt.axis('off')
    except FileNotFoundError:
        print(f"File not found: {filename}")

plt.show()

# %%
labels = data['label']

X_train, X_temp = train_test_split(data, test_size=0.2, stratify=labels, random_state = 42)

label_test_val = X_temp['label']

X_test, X_val = train_test_split(X_temp, test_size=0.5, stratify=label_test_val, random_state = 42)

print('The shape of train data',X_train.shape)
print('The shape of test data',X_test.shape)
print('The shape of validation data',X_val.shape)
# Out:
# The shape of train data (52, 2)
# The shape of test data (7, 2)
# The shape of validation data (7, 2)
